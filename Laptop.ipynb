# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("laptop_data.csv")

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
data.shape
# Out:
# (1303, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
data['Ram']= data['Ram'].str.replace('GB','')
data['Weight']= data['Weight'].str.replace('kg','')

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
data['Ram']= data['Ram'].astype('int32')
data['Weight']= data['Weight'].astype('float32')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.distplot(data['Price'])
# Out:
# C:\Users\Ganesh\AppData\Local\Temp\ipykernel_24336\4196895882.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
data['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=data['Company'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=data['TypeName'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(data['Inches'])
# Out:
# C:\Users\Ganesh\AppData\Local\Temp\ipykernel_24336\1445398758.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x= data['Inches'],y= data['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
data['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
# Create the 'TouchScreen' column with 1 for touchscreen and 0 for others
data['TouchScreen'] = data['ScreenResolution'].apply(lambda x: 1 if 'touchscreen' in x.lower() else 0)
data.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 518       HP            Notebook    15.6
# 51      Acer            Notebook    15.6
# 867   Lenovo  2 in 1 Convertible    13.3
# 1170      HP            Notebook    15.6
# 535     Dell            Notebook    15.6
#
#                                ScreenResolution                         Cpu  \
# 518                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 51                  IPS Panel Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
# 867   IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i7 7500U 2.7GHz
# 1170                          Full HD 1920x1080  Intel Core i7 6500U 2.5GHz
# 535                           Full HD 1920x1080  Intel Core i7 7600U 2.8GHz
#
#       Ram     Memory                    Gpu       OpSys  Weight      Price  \
# 518     8  256GB SSD   Nvidia GeForce 930MX  Windows 10    2.04   47365.92
# 51      8  256GB SSD   Nvidia GeForce MX150  Windows 10    2.20   44808.48
# ...

# %%
data['TouchScreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TouchScreen'>

# %%
sns.barplot(x= data['TouchScreen'],y= data['Price'])
# Out:
# <Axes: xlabel='TouchScreen', ylabel='Price'>

# %%
data['IPS'] = data['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)
data.sample(5)
# Out:
#     Company  TypeName  Inches   ScreenResolution  \
# 916      HP  Notebook    13.3  Full HD 1920x1080
# 453  Lenovo  Notebook    14.0  Full HD 1920x1080
# 127    Asus  Notebook    14.0           1366x768
# 365      HP  Notebook    15.6           1366x768
# 267  Lenovo  Notebook    15.6  Full HD 1920x1080
#
#                                       Cpu  Ram     Memory  \
# 916            Intel Core i5 7200U 2.5GHz    8  256GB SSD
# 453            Intel Core i5 7200U 2.5GHz    8  256GB SSD
# 127              AMD E-Series 6110 1.5GHz    4   64GB SSD
# 365  Intel Pentium Quad Core N3710 1.6GHz    8    2TB HDD
# 267            Intel Core i5 7200U 2.5GHz    4    1TB HDD
#
#                        Gpu         OpSys  Weight       Price  TouchScreen  IPS
# 916  Intel HD Graphics 620    Windows 10    1.49  51148.8000            0    0
# 453  Intel HD Graphics 620    Windows 10    1.65  71661.6000            0    0
# 127          AMD Radeon R2  Windows 10 S    1.65  14811.3072            0    0
# ...

# %%
data['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x= data['IPS'],y= data['Price'])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
new= data['ScreenResolution'].str.split('x', n=1, expand=True)

# %%
data['x_res']= new[0]
data['y_res']= new[1]

# %%
data.sample(4)
# Out:
#      Company            TypeName  Inches  \
# 1016      HP            Notebook    15.6
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1246    Dell            Notebook    14.0
# 279   Lenovo            Notebook    17.3
#
#                                 ScreenResolution                         Cpu  \
# 1016                                    1366x768  Intel Core i3 7100U 2.4GHz
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800  Intel Core i7 6500U 2.5GHz
# 1246                                    1366x768  Intel Core i5 7200U 2.5GHz
# 279                            Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
#
#       Ram     Memory                    Gpu       OpSys  Weight       Price  \
# 1016    4  256GB SSD  Intel HD Graphics 620  Windows 10    2.04  41025.0672
# 1299   16  512GB SSD  Intel HD Graphics 520  Windows 10    1.30  79866.7200
# 1246    4  500GB HDD  Intel HD Graphics 620  Windows 10    1.60  46620.0000
# ...

# %%
data['x_res']= data['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
data.sample(5)
# Out:
#      Company     TypeName  Inches             ScreenResolution  \
# 410   Lenovo  Workstation    15.6            Full HD 1920x1080
# 612     Dell     Notebook    15.6                     1366x768
# 1066    Asus       Gaming    17.3  IPS Panel Full HD 1920x1080
# 125       HP     Notebook    15.6                     1366x768
# 1184      HP     Notebook    15.6  IPS Panel Full HD 1920x1080
#
#                                        Cpu  Ram     Memory  \
# 410            Intel Core i7 7700HQ 2.8GHz    8  512GB SSD
# 612             Intel Core i3 6006U 2.0GHz    4    1TB HDD
# 1066           Intel Core i7 6820HK 2.7GHz   64    1TB SSD
# 125   Intel Celeron Dual Core N3060 1.6GHz    4  500GB HDD
# 1184           Intel Core i7 6700HQ 2.6GHz    6    1TB HDD
#
#                           Gpu       OpSys  Weight       Price  TouchScreen  \
# 410       Nvidia Quadro M1200  Windows 10    2.67  102564.000            0
# 612     Intel HD Graphics 520       Linux    2.18   23650.992            0
# ...

# %%
data['x_res']= data['x_res'].astype('int')
data['y_res']= data['y_res'].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  TouchScreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
num_data= data.select_dtypes(include=[float, int])
num_data.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# IPS            0.252208
# x_res          0.556529
# y_res          0.552809
# Name: Price, dtype: float64

# %%
# PPI Pixel per Inches
data['PPI']= (((data['x_res']**2) + (data['y_res']**2))**0.5/data['Inches']).astype('float')
num_data['PPI']= (((data['x_res']**2) + (data['y_res']**2))**0.5/data['Inches']).astype('float')

# %%
num_data.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# IPS            0.252208
# x_res          0.556529
# y_res          0.552809
# PPI            0.473487
# Name: Price, dtype: float64

# %%
# data.drop(columns=['ScreenResolution','Inches','x_res','y_res'],inplace= True)
data.sample(5)   # drop ScreenResolution,inches,x_res,y_res
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 589     Asus    Gaming    17.3  IPS Panel Full HD 1920x1080
# 377     Dell  Notebook    15.6                     1366x768
# 1244      HP  Notebook    14.0            Full HD 1920x1080
# 1199     MSI    Gaming    17.3            Full HD 1920x1080
# 257       HP  Notebook    17.3  IPS Panel Full HD 1920x1080
#
#                                         Cpu  Ram                Memory  \
# 589             Intel Core i5 7300HQ 2.5GHz    8  128GB SSD +  1TB HDD
# 377   Intel Celeron Dual Core N3060 1.60GHz    4             500GB HDD
# 1244             Intel Core i5 6200U 2.3GHz    4             256GB SSD
# 1199            Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 257              Intel Core i7 8550U 1.8GHz   16               1TB HDD
#
#                           Gpu       OpSys  Weight        Price  TouchScreen  \
# 589   Nvidia GeForce GTX 1060  Windows 10    2.73   94305.6000            0
# ...

# %%
data['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
data['cpu_name']= data['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
data.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 818     Dell              Gaming    17.3
# 1241    Asus           Ultrabook    13.3
# 1005      HP            Notebook    14.0
# 1270  Lenovo  2 in 1 Convertible    14.0
# 770     Dell            Notebook    15.6
#
#                                ScreenResolution                          Cpu  \
# 818                 IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 1241                          Full HD 1920x1080   Intel Core i7 6500U 2.5GHz
# 1005                                   1366x768   Intel Core i5 6300U 2.4GHz
# 1270  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 6500U 2.5GHz
# 770                           Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
#
#       Ram                Memory                      Gpu       OpSys  Weight  \
# 818    16  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10    4.36
# 1241    8             256GB SSD    Intel HD Graphics 520  Windows 10    1.45
# ...

# %%
# fetch processor
def fetch_processor(text):
    if text== 'Intel Core i7' or text== 'Intel Core i5' or text== 'Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
data['cpu_brand']= data['cpu_name'].apply(fetch_processor)

# %%
data.sample(5)
# Out:
#      Company  TypeName  Inches   ScreenResolution  \
# 189     Dell  Notebook    17.3  Full HD 1920x1080
# 1049    Asus   Netbook    11.6           1366x768
# 1174  Lenovo  Notebook    15.6  Full HD 1920x1080
# 751       HP  Notebook    15.6  Full HD 1920x1080
# 536     Dell  Notebook    15.6  Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 189             Intel Core i7 8550U 1.8GHz    8  128GB SSD +  1TB HDD
# 1049  Intel Celeron Dual Core N3060 1.6GHz    4    16GB Flash Storage
# 1174            Intel Core i7 7500U 2.7GHz    8               1TB HDD
# 751             Intel Core i5 6300U 2.4GHz    8             256GB SSD
# 536             Intel Core i5 8250U 1.6GHz    8             256GB SSD
#
#                         Gpu       OpSys  Weight        Price  TouchScreen  \
# 189          AMD Radeon 530  Windows 10    2.80   57808.8000            0
# 1049  Intel HD Graphics 400   Chrome OS    1.20   15339.3120            0
# ...

# %%
data['cpu_brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cpu_brand'>

# %%
sns.barplot(x= data['cpu_brand'],y= data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data.drop(columns=['Cpu','cpu_name'])
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  Ram               Memory  \
# 0             IPS Panel Retina Display 2560x1600    8            128GB SSD
# 1                                       1440x900    8  128GB Flash Storage
# 2                              Full HD 1920x1080    8            256GB SSD
# 3             IPS Panel Retina Display 2880x1800   16            512GB SSD
# 4             IPS Panel Retina Display 2560x1600    8            256GB SSD
# ...

# %%
data['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x= data['Ram'],y= data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
data['Memory']= data['Memory'].astype(str).replace('\.0','',regex= True)
data['Memory']= data['Memory'].str.replace('GB','')
data['Memory']= data['Memory'].str.replace('TB','000')
new= data['Memory'].str.split("+",n=1,expand= True)

data["first"]= new[0]
data["first"]= data["first"].str.strip()

data["second"]=new[1]

data["Layer1HDD"]= data["first"].apply(lambda x:1 if "HDD" in x else 0)
data["Layer1SSD"]= data["first"].apply(lambda x:1 if "SSD" in x else 0)
data["Layer1Hybrid"]= data["first"].apply(lambda x:1 if "Hybrid" in x else 0)
data["Layer1Flash_Storage"]= data["first"].apply(lambda x:1 if "Flash_Storage" in x else 0)

data['first']= data['first'].str.replace(r'\D','')
data['second'].fillna("0",inplace= True)

data["Layer2HDD"]= data["second"].apply(lambda x:1 if "HDD" in x else 0)
data["Layer2SSD"]= data["second"].apply(lambda x:1 if "SSD" in x else 0)
data["Layer2Hybrid"]= data["second"].apply(lambda x:1 if "Hybrid" in x else 0)
data["Layer2Flash_Storage"]= data["second"].apply(lambda x:1 if "Flash_Storage" in x else 0)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\Ganesh\AppData\Local\Temp\ipykernel_24336\1724747192.py:1: SyntaxWarning: invalid escape sequence '\.'
#   data['Memory']= data['Memory'].astype(str).replace('\.0','',regex= True)
# C:\Users\Ganesh\AppData\Local\Temp\ipykernel_24336\1724747192.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['second'].fillna("0",inplace= True)

# %%
# Check non-numeric entries in 'first' column
print(data['first'][~data['first'].str.isnumeric()])

# Check non-numeric entries in 'second' column
print(data['second'][~data['second'].str.isnumeric()])
# Out:
# 0                 128 SSD
# 1       128 Flash Storage
# 2                 256 SSD
# 3                 512 SSD
# 4                 256 SSD
#               ...
# 1298              128 SSD
# 1299              512 SSD
# 1300     64 Flash Storage
# 1301             1000 HDD
# 1302              500 HDD
# Name: first, Length: 1303, dtype: object
# 21        1000 HDD
# 28         256 SSD
# 37        1000 HDD
# 41        1000 HDD
# 47        1000 HDD
#            ...
# 1238      1000 HDD
# 1245      1000 HDD
# 1247      1000 HDD
# 1256      1000 HDD
# 1259      1000 HDD
# Name: second, Length: 208, dtype: object

# %%
# Remove non-numeric characters and fill missing values with "0"
data['first'] = data['first'].str.replace(r'\D', '', regex=True).fillna("0")
data['second'] = data['second'].str.replace(r'\D', '', regex=True).fillna("0")

# %%
data['first'] = data['first'].astype(int)
data['second'] = data['second'].astype(int)

# %%
data["HDD"]= (data['first']*data["Layer1HDD"]+data["second"]*data["Layer2HDD"])
data["SSD"]= (data['first']*data["Layer1SSD"]+data["second"]*data["Layer2SSD"])
data["Hybrid"]= (data['first']*data["Layer1Hybrid"]+data["second"]*data["Layer2Hybrid"])
data["Flash_Storage"]= (data['first']*data["Layer1Flash_Storage"]+data["second"]*data["Layer2Flash_Storage"])

# %%
data.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash_Storage','Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash_Storage'],inplace= True)

# %%
data.sample(5)
# Out:
#      Company   TypeName  Inches             ScreenResolution  \
# 1217  Lenovo   Notebook    17.3                     1600x900
# 135       HP   Notebook    14.0            Full HD 1920x1080
# 992   Lenovo   Notebook    15.6                     1366x768
# 507     Acer   Notebook    15.6  IPS Panel Full HD 1920x1080
# 1289    Asus  Ultrabook    13.3  IPS Panel Full HD 1920x1080
#
#                                        Cpu  Ram    Memory  \
# 1217            Intel Core i5 7200U 2.5GHz    8  1000 HDD
# 135             Intel Core i7 8550U 1.8GHz    8   256 SSD
# 992   Intel Celeron Dual Core N3350 1.1GHz    4   128 SSD
# 507             Intel Core i5 8250U 1.6GHz    4  1000 HDD
# 1289              Intel Core M 6Y30 0.9GHz    8   512 SSD
#
#                          Gpu       OpSys  Weight  ...  IPS  x_res  y_res  \
# 1217   Intel HD Graphics 620       No OS    2.80  ...    0   1600    900
# 135   Intel UHD Graphics 620  Windows 10    1.63  ...    0   1920   1080
# ...

# %%
data.drop(columns= ['Memory'],inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz    8  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz    8        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz    8         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz   16            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  ...  IPS  x_res  y_res         PPI       cpu_name  \
# ...

# %%
num_data= data.select_dtypes(include=[float, int])
num_data.corr()['Price']
# Out:
# Inches           0.068197
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# TouchScreen      0.191226
# IPS              0.252208
# x_res            0.556529
# y_res            0.552809
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage         NaN
# Name: Price, dtype: float64

# %%
data.drop(columns=['Hybrid','Flash_Storage'],inplace= True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz    8  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz    8        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz    8         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz   16            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  TouchScreen  IPS  x_res  y_res         PPI  \
# 0    1.37   71378.6832            0    1   2560   1600  226.983005
# ...

# %%
data['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
data['Gpu_brand']= data['Gpu'].apply(lambda x:x.split()[0])

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz    8  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz    8        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz    8         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz   16            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  TouchScreen  IPS  x_res  y_res         PPI  \
# 0    1.37   71378.6832            0    1   2560   1600  226.983005
# ...

# %%
data['Gpu_brand'].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
data= data[data['Gpu_brand']!= 'ARM']

# %%
data['Gpu_brand'].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x= data['Gpu_brand'],y= data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data.drop(columns=['Gpu'],inplace= True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram  OpSys  Weight        Price  TouchScreen  \
# 0        Intel Core i5 2.3GHz    8  macOS    1.37   71378.6832            0
# 1        Intel Core i5 1.8GHz    8  macOS    1.34   47895.5232            0
# 2  Intel Core i5 7200U 2.5GHz    8  No OS    1.86   30636.0000            0
# 3        Intel Core i7 2.7GHz   16  macOS    1.83  135195.3360            0
# 4        Intel Core i5 3.1GHz    8  macOS    1.37   96095.8080            0
#
#    IPS  x_res  y_res         PPI       cpu_name      cpu_brand  HDD  SSD  \
# ...

# %%
data['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=data['OpSys'],y= data['Price'])
plt.xticks(rotation= "vertical")
plt.show()

# %%
def cat_os(inp):
    if inp== 'Windows 10' or inp== 'Windows 7' or inp== 'Windows 10 S':
        return 'Windows'
    elif inp== 'macOS' or inp== 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
data['OS']= data['OpSys'].apply(cat_os)

# %%
data.sample(4)
# Out:
#       Company   TypeName  Inches                 ScreenResolution  \
# 963   Toshiba  Ultrabook    12.5  Full HD / Touchscreen 1920x1080
# 1231    Razer     Gaming    14.0                Full HD 1920x1080
# 549    Lenovo   Notebook    15.6      IPS Panel Full HD 1920x1080
# 1151       HP   Notebook    15.6                         1366x768
#
#                               Cpu  Ram       OpSys  Weight      Price  \
# 963    Intel Core i7 7500U 2.7GHz    8  Windows 10    1.10   95371.20
# 1231  Intel Core i7 7700HQ 2.8GHz   16  Windows 10    1.95  186426.72
# 549    Intel Core i7 7500U 2.7GHz    8  Windows 10    1.99   92121.12
# 1151     AMD E-Series 7110 1.8GHz    4  Windows 10    1.86   15824.16
#
#       TouchScreen  IPS  x_res  y_res         PPI           cpu_name  \
# 963             1    0   1920   1080  176.232574      Intel Core i7
# 1231            0    0   1920   1080  157.350512      Intel Core i7
# 549             0    1   1920   1080  141.211998      Intel Core i7
# ...

# %%
data.drop(columns=['OpSys'],inplace= True)

# %%
sns.barplot(x=data['OS'],y= data['Price'])
#plt.xticks(rotation= "vertical")
plt.show()

# %%
sns.distplot(data['Weight'])
# Out:
# C:\Users\Ganesh\AppData\Local\Temp\ipykernel_24336\2799343561.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x= data['Weight'],y= data['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
num_data= data.select_dtypes(include=[float, int])
num_data.corr()['Price']
# Out:
# Inches         0.067329
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# TouchScreen    0.192917
# IPS            0.253320
# x_res          0.557369
# y_res          0.554591
# PPI            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
sns.heatmap(num_data.corr())
# Out:
# <Axes: >

# %%
sns.distplot(np.log(data['Price']))
# Out:
# C:\Users\Ganesh\AppData\Local\Temp\ipykernel_24336\460424880.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(data['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
data= data.drop(columns=['Cpu','cpu_name'])

# %%
data= data.drop(columns=['Inches','ScreenResolution','x_res','y_res'])

# %%
data.sample(4)
# Out:
#      Company   TypeName  Ram  Weight     Price  TouchScreen  IPS         PPI  \
# 576  Toshiba  Ultrabook   16    1.24  99367.20            1    0  157.350512
# 440   Lenovo   Notebook    8    2.80  27652.32            0    0  106.113062
# 961   Lenovo  Ultrabook    8    1.36  93772.80            0    1  176.232574
# 99        HP     Gaming   12    2.62  66546.72            0    1  141.211998
#
#          cpu_brand   HDD  SSD Gpu_brand       OS
# 576  Intel Core i7     0  512     Intel  Windows
# 440  AMD Processor  1000    0       AMD  Windows
# 961  Intel Core i5     0  256     Intel  Windows
# 99   Intel Core i7  1000  128    Nvidia  Windows

# %%
x= data.drop(columns=['Price'])
y= np.log(data['Price'])

# %%
x
# Out:
#      Company            TypeName  Ram  Weight  TouchScreen  IPS         PPI  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.15,random_state=2)

# %%
x_train
# Out:
#       Company            TypeName  Ram  Weight  TouchScreen  IPS         PPI  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...

# %%
data.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  TouchScreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        cpu_brand  HDD  SSD Gpu_brand                  OS
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Random Forest

# %%
step1= ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2= RandomForestRegressor(n_estimators=300,
                             random_state=3,
                             max_samples=0.99,
                             max_features= 0.10,
                             max_depth= 20)

pipe= Pipeline([
    ('step1',step1),
    ('step2',step2),
])

pipe.fit(x_train,y_train)

y_pred= pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
print('Mean Absolute Error',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9070273238442821
# Mean Absolute Error 0.14275375488485376

# %%
data
# Out:
#      Company            TypeName  Ram  Weight        Price  TouchScreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
# from sklearn.model_selection import GridSearchCV

# param_grid = {
#     'step2__n_estimators': [300, 500, 700],
#     'step2__max_features': [0.1, 0.2, 0.3],
#     'step2__max_depth': [20, 30, None],
#     'step2__min_samples_split': [2, 5, 10]
# }

# grid_search = GridSearchCV(pipe, param_grid, cv=5, scoring='r2')
# grid_search.fit(x_train, y_train)

# print('Best R2 score from GridSearch:', grid_search.best_score_)
# print('Best Parameters:', grid_search.best_params_)

# %% [markdown]
# # Exporting the model

# %%
import pickle
pickle.dump(data,open('laptop_data1.pkl','wb'))
pickle.dump(pipe,open('pipe1.pkl','wb') )
